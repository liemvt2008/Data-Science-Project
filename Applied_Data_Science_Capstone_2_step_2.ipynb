# %% [markdown]
# ## Scraping the data from Wikipedia page

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
website_url = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
from bs4 import BeautifulSoup
import lxml.etree
soup = BeautifulSoup(website_url,'html.parser')
#print(soup.prettify())

# %%
table = soup.find('table',{'class':'wikitable sortable'})
table_rows = table.find_all('tr')

# %%
data = []
for row in table_rows:
    data.append([t.text.strip() for t in row.find_all('td')])

# %%
df = pd.DataFrame(data, columns=['PostalCode', 'Borough', 'Neighbourhood'])
df = df[~df['PostalCode'].isnull()]  # to filter out bad rows

# %%
df.head()
# Out:
#   PostalCode           Borough     Neighbourhood
# 1        M1A      Not assigned      Not assigned
# 2        M2A      Not assigned      Not assigned
# 3        M3A        North York         Parkwoods
# 4        M4A        North York  Victoria Village
# 5        M5A  Downtown Toronto      Harbourfront

# %% [markdown]
# ### Only process the cells that have an assigned borough. Ignore cells with a borough that is Not assigned.

# %%
df.drop(df[df['Borough']=="Not assigned"].index,axis=0, inplace=True)

# %% [markdown]
# ### Combined into one row with the neighborhoods separated with a comma

# %%
df1=df.groupby("PostalCode").agg(lambda x:','.join(set(x)))

# %% [markdown]
# ### If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough

# %%
df1.loc[df1['Neighbourhood']=="Not assigned",'Neighbourhood']=df1.loc[df1['Neighbourhood']=="Not assigned",'Borough']
df1.head()
# Out:
#                 Borough                         Neighbourhood
# PostalCode
# M1B         Scarborough                         Malvern,Rouge
# M1C         Scarborough  Rouge Hill,Highland Creek,Port Union
# M1E         Scarborough       Guildwood,Morningside,West Hill
# M1G         Scarborough                                Woburn
# M1H         Scarborough                             Cedarbrae

# %% [markdown]
# ### In the last cell of your notebook, use the .shape method to print the number of rows of your dataframe.

# %%
df1.shape
# Out:
# (103, 2)

# %% [markdown]
# ## Get the latitude and the longitude coordinates of each neighborhood.

# %%
geo_data=pd.read_csv("https://cocl.us/Geospatial_data")
geo_data.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df1['Latitude']=geo_data['Latitude'].values
df1['Longitude']=geo_data['Longitude'].values
df1
# Out:
#                      Borough  \
# PostalCode
# M1B              Scarborough
# M1C              Scarborough
# M1E              Scarborough
# M1G              Scarborough
# M1H              Scarborough
# M1J              Scarborough
# M1K              Scarborough
# M1L              Scarborough
# M1M              Scarborough
# M1N              Scarborough
# M1P              Scarborough
# M1R              Scarborough
# M1S              Scarborough
# M1T              Scarborough
# M1V              Scarborough
# M1W              Scarborough
# M1X              Scarborough
# M2H               North York
# M2J               North York
# M2K               North York
# M2L               North York
# M2M               North York
# M2N               North York
# M2P               North York
# M2R               North York
# M3A               North York
# M3B               North York
# M3C               North York
# M3H               North York
# M3J               North York
# M3K               North York
# M3L               North York
# M3M               North York
# M3N               North York
# M4A               North York
# M4B                East York
# M4C                East York
# M4E             East Toronto
# M4G                East York
# M4H                East York
# M4J                East York
# M4K             East Toronto
# M4L             East Toronto
# M4M             East Toronto
# M4N          Central Toronto
# M4P          Central Toronto
# M4R          Central Toronto
# M4S          Central Toronto
# M4T          Central Toronto
# M4V          Central Toronto
# M4W         Downtown Toronto
# M4X         Downtown Toronto
# M4Y         Downtown Toronto
# M5A         Downtown Toronto
# M5B         Downtown Toronto
# M5C         Downtown Toronto
# M5E         Downtown Toronto
# M5G         Downtown Toronto
# M5H         Downtown Toronto
# M5J         Downtown Toronto
# M5K         Downtown Toronto
# M5L         Downtown Toronto
# M5M               North York
# M5N          Central Toronto
# M5P          Central Toronto
# M5R          Central Toronto
# M5S         Downtown Toronto
# M5T         Downtown Toronto
# M5V         Downtown Toronto
# M5W         Downtown Toronto
# M5X         Downtown Toronto
# M6A               North York
# M6B               North York
# M6C                     York
# M6E                     York
# M6G         Downtown Toronto
# M6H             West Toronto
# M6J             West Toronto
# M6K             West Toronto
# M6L               North York
# M6M                     York
# M6N                     York
# M6P             West Toronto
# M6R             West Toronto
# M6S             West Toronto
# M7A             Queen's Park
# M7R              Mississauga
# M7Y             East Toronto
# M8V                Etobicoke
# M8W                Etobicoke
# M8X                Etobicoke
# M8Y                Etobicoke
# M8Z                Etobicoke
# M9A                Etobicoke
# M9B                Etobicoke
# M9C                Etobicoke
# M9L               North York
# M9M               North York
# M9N                     York
# M9P                Etobicoke
# M9R                Etobicoke
# M9V                Etobicoke
# M9W                Etobicoke
#
#                                                 Neighbourhood   Latitude  \
# PostalCode
# M1B                                             Malvern,Rouge  43.806686
# M1C                      Rouge Hill,Highland Creek,Port Union  43.784535
# M1E                           Guildwood,Morningside,West Hill  43.763573
# M1G                                                    Woburn  43.770992
# M1H                                                 Cedarbrae  43.773136
# M1J                                       Scarborough Village  43.744734
# M1K                 East Birchmount Park,Ionview,Kennedy Park  43.727929
# M1L                             Oakridge,Golden Mile,Clairlea  43.711112
# M1M             Cliffcrest,Cliffside,Scarborough Village West  43.716316
# M1N                                Cliffside West,Birch Cliff  43.692657
# M1P         Dorset Park,Wexford Heights,Scarborough Town C...  43.757410
# M1R                                          Maryvale,Wexford  43.750072
# M1S                                                 Agincourt  43.794200
# M1T                     Tam O'Shanter,Sullivan,Clarks Corners  43.781638
# M1V         Steeles East,Agincourt North,L'Amoreaux East,M...  43.815252
# M1W                              Steeles West,L'Amoreaux West  43.799525
# M1X                                               Upper Rouge  43.836125
# M2H                                         Hillcrest Village  43.803762
# M2J                                Henry Farm,Fairview,Oriole  43.778517
# M2K                                           Bayview Village  43.786947
# M2L                                   Silver Hills,York Mills  43.757490
# M2M                                    Newtonbrook,Willowdale  43.789053
# M2N                                          Willowdale South  43.770120
# M2P                                           York Mills West  43.752758
# M2R                                           Willowdale West  43.782736
# M3A                                                 Parkwoods  43.753259
# M3B                                           Don Mills North  43.745906
# M3C                           Flemingdon Park,Don Mills South  43.725900
# M3H             Bathurst Manor,Wilson Heights,Downsview North  43.754328
# M3J                            Northwood Park,York University  43.767980
# M3K                                CFB Toronto,Downsview East  43.737473
# M3L                                            Downsview West  43.739015
# M3M                                         Downsview Central  43.728496
# M3N                                       Downsview Northwest  43.761631
# M4A                                          Victoria Village  43.725882
# M4B                            Parkview Hill,Woodbine Gardens  43.706397
# M4C                                          Woodbine Heights  43.695344
# M4E                                               The Beaches  43.676357
# M4G                                                   Leaside  43.709060
# M4H                                          Thorncliffe Park  43.705369
# M4J                                              East Toronto  43.685347
# M4K                               The Danforth West,Riverdale  43.679557
# M4L                             The Beaches West,India Bazaar  43.668999
# M4M                                           Studio District  43.659526
# M4N                                             Lawrence Park  43.728020
# M4P                                          Davisville North  43.712751
# M4R                                        North Toronto West  43.715383
# M4S                                                Davisville  43.704324
# M4T                                Moore Park,Summerhill East  43.689574
# M4V         South Hill,Rathnelly,Deer Park,Summerhill West...  43.686412
# M4W                                                  Rosedale  43.679563
# M4X                                St. James Town,Cabbagetown  43.667967
# M4Y                                      Church and Wellesley  43.665860
# M5A                                  Harbourfront,Regent Park  43.654260
# M5B                                   Garden District,Ryerson  43.657162
# M5C                                            St. James Town  43.651494
# M5E                                               Berczy Park  43.644771
# M5G                                        Central Bay Street  43.657952
# M5H                                    King,Richmond,Adelaide  43.650571
# M5J           Union Station,Harbourfront East,Toronto Islands  43.640816
# M5K                   Toronto Dominion Centre,Design Exchange  43.647177
# M5L                             Commerce Court,Victoria Hotel  43.648198
# M5M                          Bedford Park,Lawrence Manor East  43.733283
# M5N                                                  Roselawn  43.711695
# M5P                        Forest Hill West,Forest Hill North  43.696948
# M5R                         North Midtown,The Annex,Yorkville  43.672710
# M5S                             Harbord,University of Toronto  43.662696
# M5T                   Grange Park,Kensington Market,Chinatown  43.653206
# M5V         Railway Lands,Harbourfront West,Island airport...  43.628947
# M5W                           Stn A PO Boxes 25 The Esplanade  43.646435
# M5X                     First Canadian Place,Underground city  43.648429
# M6A                           Lawrence Manor,Lawrence Heights  43.718518
# M6B                                                 Glencairn  43.709577
# M6C                                        Humewood-Cedarvale  43.693781
# M6E                                       Caledonia-Fairbanks  43.689026
# M6G                                                  Christie  43.669542
# M6H                               Dovercourt Village,Dufferin  43.669005
# M6J                                   Little Portugal,Trinity  43.647927
# M6K                Parkdale Village,Brockton,Exhibition Place  43.636847
# M6L                    North Park,Upwood Park,Maple Leaf Park  43.713756
# M6M               Mount Dennis,Del Ray,Keelesdale,Silverthorn  43.691116
# M6N                              Runnymede,The Junction North  43.673185
# M6P                              The Junction South,High Park  43.661608
# M6R                                     Roncesvalles,Parkdale  43.648960
# M6S                                         Runnymede,Swansea  43.651571
# M7A                                              Queen's Park  43.662301
# M7R                     Canada Post Gateway Processing Centre  43.636966
# M7Y         Business Reply Mail Processing Centre 969 Eastern  43.662744
# M8V                Humber Bay Shores,New Toronto,Mimico South  43.605647
# M8W                                     Long Branch,Alderwood  43.602414
# M8X               Old Mill North,The Kingsway,Montgomery Road  43.653654
# M8Y         King's Mill Park,Old Mill South,Humber Bay,Kin...  43.636258
# M8Z         Mimico NW,The Queensway West,Royal York South ...  43.628841
# M9A                                          Islington Avenue  43.667856
# M9B         Martin Grove,West Deane Park,Princess Gardens,...  43.650943
# M9C         Markland Wood,Bloordale Gardens,Old Burnhamtho...  43.643515
# M9L                                             Humber Summit  43.756303
# M9M                                           Humberlea,Emery  43.724766
# M9N                                                    Weston  43.706876
# M9P                                                 Westmount  43.696319
# M9R         Kingsview Village,Martin Grove Gardens,Richvie...  43.688905
# M9V         Beaumond Heights,South Steeles,Mount Olive,Jam...  43.739416
# M9W                                                 Northwest  43.706748
#
#             Longitude
# PostalCode
# M1B        -79.194353
# M1C        -79.160497
# M1E        -79.188711
# M1G        -79.216917
# M1H        -79.239476
# M1J        -79.239476
# M1K        -79.262029
# M1L        -79.284577
# M1M        -79.239476
# M1N        -79.264848
# M1P        -79.273304
# M1R        -79.295849
# M1S        -79.262029
# M1T        -79.304302
# M1V        -79.284577
# M1W        -79.318389
# M1X        -79.205636
# M2H        -79.363452
# M2J        -79.346556
# M2K        -79.385975
# M2L        -79.374714
# M2M        -79.408493
# M2N        -79.408493
# M2P        -79.400049
# M2R        -79.442259
# M3A        -79.329656
# M3B        -79.352188
# M3C        -79.340923
# M3H        -79.442259
# M3J        -79.487262
# M3K        -79.464763
# M3L        -79.506944
# M3M        -79.495697
# M3N        -79.520999
# M4A        -79.315572
# M4B        -79.309937
# M4C        -79.318389
# M4E        -79.293031
# M4G        -79.363452
# M4H        -79.349372
# M4J        -79.338106
# M4K        -79.352188
# M4L        -79.315572
# M4M        -79.340923
# M4N        -79.388790
# M4P        -79.390197
# M4R        -79.405678
# M4S        -79.388790
# M4T        -79.383160
# M4V        -79.400049
# M4W        -79.377529
# M4X        -79.367675
# M4Y        -79.383160
# M5A        -79.360636
# M5B        -79.378937
# M5C        -79.375418
# M5E        -79.373306
# M5G        -79.387383
# M5H        -79.384568
# M5J        -79.381752
# M5K        -79.381576
# M5L        -79.379817
# M5M        -79.419750
# M5N        -79.416936
# M5P        -79.411307
# M5R        -79.405678
# M5S        -79.400049
# M5T        -79.400049
# M5V        -79.394420
# M5W        -79.374846
# M5X        -79.382280
# M6A        -79.464763
# M6B        -79.445073
# M6C        -79.428191
# M6E        -79.453512
# M6G        -79.422564
# M6H        -79.442259
# M6J        -79.419750
# M6K        -79.428191
# M6L        -79.490074
# M6M        -79.476013
# M6N        -79.487262
# M6P        -79.464763
# M6R        -79.456325
# M6S        -79.484450
# M7A        -79.389494
# M7R        -79.615819
# M7Y        -79.321558
# M8V        -79.501321
# M8W        -79.543484
# M8X        -79.506944
# M8Y        -79.498509
# M8Z        -79.520999
# M9A        -79.532242
# M9B        -79.554724
# M9C        -79.577201
# M9L        -79.565963
# M9M        -79.532242
# M9N        -79.518188
# M9P        -79.532242
# M9R        -79.554724
# M9V        -79.588437
# M9W        -79.594054
